# %%
df = spark.read.table("workspace.silver_prd.orders_consolidated")

# %%
len(df.columns) #30

# %%
df.limit(10).display()

# %%
df2 = spark.read.table("workspace.gold_prd.customer_summary")

# %%
df2.limit(10).display()
